# %%
# importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import datasets,models,layers

# %%
# loading the dataset
(x_train,y_train),(x_test,y_test) = datasets.mnist.load_data()
# Out:
# ...
# 11490434/11490434 [==============================] - 2s 0us/step

# %%
from matplotlib import pyplot
for i in range(6):  
  pyplot.subplot(330 + 1 + i)
  pyplot.imshow(x_train[i], cmap=pyplot.get_cmap('gray'))
  pyplot.show()
  print()

# %%
# finding the shape of training and test sets
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
# Scaling the features

x_train_scaled = x_train/255
x_test_scaled = x_test/255

# %%
x_train = x_train.reshape(-1,28,28,1)
x_train.shape
# Out:
# (60000, 28, 28, 1)

# %%
x_test1 = x_test.reshape(-1,28,28,1)
x_test1.shape
# Out:
# (10000, 28, 28, 1)

# %%
model = keras.Sequential([
    layers.Conv2D(30,(3,3),activation = 'relu',input_shape = (28,28,1)),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(30,(3,3),activation = 'relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(30,(3,3),activation = 'relu'),
    layers.MaxPooling2D((2,2)),
    
    layers.Flatten(),
    layers.Dense(100,activation='relu'),
    layers.Dropout(0.5),
    keras.layers.Dense(10,activation='sigmoid')
])

# %%
model.compile(
    optimizer= 'adam',
    loss = 'sparse_categorical_crossentropy',
    metrics = ['accuracy']
)
model.fit(x_train,y_train,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 23s 4ms/step - loss: 0.8160 - accuracy: 0.7451
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1664 - accuracy: 0.9549
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1205 - accuracy: 0.9663
# Epoch 4/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0995 - accuracy: 0.9725
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0878 - accuracy: 0.9757

# %%
model.evaluate(x_test1,y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0987 - accuracy: 0.9734
# [0.09872181713581085, 0.9733999967575073]

# %%
y_predicted = model.predict(x_test1)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
y_predicted = [np.argmax(i) for i in y_predicted]

# %%
print(y_predicted)
# Out:
# [7, 2, 1, 0, 4, 1, 4, 9, 5, 9, 0, 6, 9, 0, 1, 5, 9, 7, 3, 4, 9, 6, 6, 5, 4, 0, 7, 4, 0, 1, 3, 1, 3, 4, 7, 2, 7, 1, 2, 1, 1, 2, 4, 2, 3, 5, 1, 2, 4, 4, 6, 3, 5, 5, 6, 0, 4, 1, 9, 5, 7, 8, 9, 3, 7, 4, 6, 4, 3, 0, 7, 0, 2, 9, 1, 7, 3, 2, 9, 7, 7, 6, 2, 7, 8, 4, 7, 3, 6, 1, 3, 6, 9, 3, 1, 4, 0, 7, 6, 9, 6, 0, 5, 4, 9, 9, 2, 1, 9, 4, 8, 2, 3, 9, 7, 4, 4, 4, 9, 2, 5, 4, 7, 6, 7, 9, 0, 5, 8, 5, 6, 6, 5, 7, 8, 1, 0, 1, 6, 4, 6, 7, 2, 1, 7, 1, 8, 2, 0, 2, 9, 9, 5, 5, 1, 5, 6, 0, 2, 4, 4, 6, 5, 4, 6, 5, 4, 5, 1, 4, 4, 7, 2, 3, 2, 7, 1, 8, 1, 8, 1, 8, 5, 0, 2, 9, 2, 5, 0, 1, 1, 1, 0, 9, 0, 3, 1, 6, 4, 2, 3, 6, 1, 1, 1, 3, 9, 5, 2, 9, 4, 5, 9, 3, 9, 0, 3, 6, 5, 5, 7, 2, 2, 7, 1, 2, 8, 4, 1, 7, 3, 3, 8, 8, 2, 9, 2, 2, 4, 1, 5, 9, 8, 7, 2, 3, 0, 2, 4, 2, 4, 1, 9, 5, 7, 7, 2, 8, 2, 6, 8, 5, 7, 7, 9, 1, 8, 1, 8, 0, 3, 0, 1, 9, 9, 4, 1, 8, 2, 1, 2, 9, 7, 5, 9, 2, 6, 4, 1, 5, 4, 2, 9, 2, 0, 4, 0, 0, 2, 8, 4, 7, 1, 2, 4, 0, 2, 7, 4, 3, 3, 0, 0, 3, 1, 9, 6, 5, 2, 5, 9, 2, 9, 3, 0, 4, 2, 0, 7, 1, 1, 2, 1
# ...

# %%
def random_check(x):
    plt.matshow(x_test[x])
    print("actula result is:",y_predicted[x])
print("to ask a number it indicates index values of 10000 images")
random_check(int(input('Enter a number in:')))
# Out:
# to ask a number it indicates index values of 10000 images
# Enter a number in:9999
# actula result is: 6

# %%
# building confusion matrix
cm = tf.math.confusion_matrix(y_test,y_predicted)
cm
# Out:
# <tf.Tensor: shape=(10, 10), dtype=int32, numpy=
# array([[ 964,    1,    5,    0,    3,    1,    0,    5,    0,    1],
#        [   2, 1122,    5,    2,    3,    0,    0,    0,    1,    0],
#        [   4,    0, 1014,    2,    1,    0,    1,   10,    0,    0],
#        [   0,    0,   12,  975,    1,    9,    0,   11,    0,    2],
#        [   2,    0,    1,    0,  972,    0,    1,    0,    0,    6],
#        [   3,    0,    3,    5,    1,  875,    2,    1,    1,    1],
#        [   7,    3,    1,    1,   12,    4,  929,    0,    1,    0],
#        [   1,    2,   31,    3,    1,    0,    0,  986,    0,    4],
#        [   9,    2,    8,    3,   19,    4,    3,    1,  908,   17],
#        [   3,    0,    0,    1,    9,    3,    0,    4,    0,  989]],
#       dtype=int32)>

# %%
plt.figure(figsize = (10,7))
sn.heatmap(cm,annot = True, fmt = 'd')
plt.xlabel('Predicted values')
plt.ylabel('Actual values')
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 26, 26, 30)        300
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 30)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 30)        8130
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 30)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 30)          8130
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 30)         0
#  2D)
#
#  flatten (Flatten)           (None, 30)                0
#
#  dense (Dense)               (None, 100)               3100
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_1 (Dense)             (None, 10)                1010
#
# ...
# Total params: 20,670
# Trainable params: 20,670
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.save("mnist.h5")
